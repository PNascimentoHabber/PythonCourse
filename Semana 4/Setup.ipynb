# %% [markdown]
# Boa tarde a todos,
#
# Bem vindos!! 🙂
#
# Este curso tem como objetivo equipar-vos com as ferramentas necessárias para começar a usar Python em Data Science. Dito isto, este curso será uma mais valia para quem tiver interesse em Data Science, ou para quem simplesmente queira ganhar conhecimentos em Python.
#
# O curso é 100% online. Uma sessão por semana de sensivelmente uma hora. Cada sessão irá cobrir um ou vários temas. Ser-vos-á enviado, após cada sessão, um documento com exercicios de modo a poderem testar o vosso conhecimento. Estarei sempre disponível para vos ajudar.
#
# Um dos objetivos é conseguirmos ter sessões dinâmicas com discussões e vários pontos de vista. Quer isto dizer que espero que mantenhamos uma relação many to many ao invés de one to many.
#
# Instalação para Windows:
#
# - Caso tenham atualizações do Windows, façam o download e instalem-nas;
# - Antes de instalarmos o subsistema Linux para Windows, confirmar se esta opção está ativa:
#     - Escrever "PowerShell" na barra de procura;
#     - Correr como Administrador;
#     - Colar o seguinte texto e enter: "Enable-WindowsOptionalFeature -Online -FeatureName Microsoft-Windows-Subsystem-Linux";
#     - Reiniciar o computador se solicitado (reiniciar em caso de dúvida);
# - Aceder à Microsoft Store e fazer o download e instalação de Ubuntu: "https://www.microsoft.com/pt-pt/p/ubuntu-1804-lts/9n9tngvndl3q?rtc=1&activetab=pivot:overviewtab";
# - Após instalação, escrever "Ubuntu" na barra de procura e abrir a aplicação;
# - Após alguns minutos a instalação está completa e aparecerá uma mensagem para criarem um user e password;
# - Após definirem o user e password, irá aparecer-vos uma janela onde podem interagir com Ubuntu;
# - Colar o seguinte texto de modo a que sejam feitas as atualizações necessárias: "sudo apt update && sudo apt upgrade && sudo apt install git" (poderá ser-vos solicitada a password acima definida).
#
# Github:
#
# Iremos usar a plataforma GitHub para guardarmos o nosso trabalho.
#
# - Criar uma conta no GitHub: "https://github.com/";
# - Criar um novo Workspace:
#     - Log in;
#     - No canto superior direito, há um botão com um "+", e depois "New repository";
#     - Definir como privado;
#     - Inicializar com um "README";
#     - Adicionar um ".gitignore" Python.
# - Abrir um janela/terminal Ubuntu;
# - Criar uma pasta onde iremos os repositórios que iremos usar. "mkdir" cria um novo diretório e "cd" leva-nos até um determinado diretório. Colar na janela Ubuntu: "mkdir ~/projects", de modo a criarmos um novo diretório, e depois colar: "cd ~/projects" de modo a entrar nesse diretório.
#
# All done for now :)

# %% [markdown]
# Boa noite a todos,
#
# Este email contém os passos necessários para finalizar a instalação de tudo o que é preciso, e um breve overview de Jupyter Notebook. Não é necessário fazerem antes de Quarta-feira. Podem fazer após a aula, terminando assim o material da semana 0, para depois começarem com o material da semana 1. Caso haja questões, coloquem-nas por favor antes ou depois da aula.
#
# Como importar o material necessário:
# - Abrir um terminal;
# - Colar "cd ~/projects";
# - Colar "git clone https://github.com/PNascimentoHabber/PythonCourse" (git clone é o código usado para importar material de um repositório GitHub);
# - Também na pasta projects, colar "git clone https://github.com/<username da vossa conta github>/<nome do repositório que criaram no github>" para criar o vosso repositório;
# - Cada semana haverá uma pasta com o material necessário no repositório do curso https://github.com/PNascimentoHabber/PythonCourse;
# - Copiar o material importado para a nova pasta que será o vosso repositório. Usamos "cp" para copiar ficheiros de um diretório para outro, e usamos também a opção "-r" para copiar não só ficheiros mas também subdiretórios que possam exitir. Colocamos primeiro o diretório a copiar e depois o destino. Então para isto, colar no vosso terminal e enter: "cp -r PythonCourse/* <nome do vosso repositório no git hub>".
#
# Criar um ambiente virtual python e instalação do que for necessário:
# - Abrir um terminal;
# - Para instalações e atualizações, colar: "sudo apt update && sudo apt upgrade && sudo apt install python3-pip python3-venv";
# - Colar: "python3 -m pip install --user --upgrade pip setuptools wheel";
# - Criar um ambiente virtual com o nome "python-venv": Colar "python3 -m venv ~/.virtualenvs/python-venv";
# - Ativar o ambiente: Colar "source ~/.virtualenvs/python-venv/bin/activate"
# - Ao ativarmos o ambiente virtual, devemos ver do lado esquerdo da linha de comando o nome do ambiente virtual dentro de parênteses;
# - Atualização: Colar "pip install -U pip" (pip é um sistema de gestão de packages usado para instalar e gerir packages usados em python);
# - Para sair do ambiente virtual, basta colar: "deactivate".
#
# Trabalhar:
# - O material virá em formato de Jupyter Notebooks (e alguns links com apresentações). Notebooks são documentos que podem conter texto, imagens e código;
# - É muito importante trabalharem sempre nos ficheiros do vosso repositório, e não nos ficheiros do repositório do curso (PythonCourse);
# - Abrir um terminal;
# - Ativar o ambiente virtual: "source ~/.virtualenvs/python-venv/bin/activate";
# - Entrarem no vosso repositório, e no diretório da respetiva semana, neste caso, é a semana 0: " cd ~/projects/my-repository/"Semana 0" ";
# - Colar "pip install -r ~/projects/my-repository/"Semana 0"/requirements.txt" (instalar os packages necessários);
# - Colar: "cd ~/projects/<nome do vosso repositório>";
# - Iniciar a aplicação Jupyter Notebook: Colar: "jupyter notebook";
# - O vosso browser deverá iniciar uma nova janela com o Jupyter aberto. Caso não aconteça, basta copiarem o link do vosso terminal que contenha a palavra "localhost" e colarem numa nova janela do vosso browser;
# - Ler o "Learning Notebook" e fazer os exercícios do "Exercice Notebook", e guardar as alterações (File -> Save and Checkpoint);
# - Sempre que queiram fechar um notebook, guardar como acima explicado, e depois na opção Kernel, escolher shutdown;
# - Para fechar o jupyter notebook, carregar em logout no canto superior direito.
#
# Commit e Push:
# - Vamos supor que já fizeram alterações nos Notebooks, gravaram as alterações no Jupyter, mas não guardaram as alterações no vosso repositório GitHub;
# - Abrir um terminal;
# - Primeiro temos que configurar o nosso email e username, lembrando-nos da conta que criámos no GitHub:
#     - Exemplo: Colar e enter " git config --global user.email "pedro.nascimento@habber.com" ";
#     - Exemplo: Colar e enter " git config --global user.username "PNascimentoHabber" ";
#     - Exemplo: Colar e enter " git config --global user.name "Pedro Nascimento" ";
# - Vamos para o repositório individual: Colar "cd ~/projects/<nome do vosso repositório>";
# - Colar "git add ." (Adiciona à staging area alterações no diretório de trabalho);
# - Colar "git commit -m" ("git commit" - Guarda as alterações no repositório local; "-m" - Permite acrescentar uma mensagem ao commit);
# - Colar "git push" (Faz o upload do conteúdo do repositório local para um repositório remoto, neste caso, para a vossa conta no GitHub);
# - Poderão assim aceder às alterações e aos ficheiros com que trabalharam, fora do subsistema linux, tendo apenas que ir à vossa conta e ao vosso repositório GitHub;
# - Para guardar estes ficheiros no vosso sistema operativo Windows.. já sabem como fazer :) (explicado num dos pontos acima).
#
# Após todos estes passos e configurações, deixo aqui o procedimento semanal:
# - Assim que o novo material esteja disponível, importar os dados do repositório remoto do curso:
#     - Colar "cd ~/projects/PythonCourse/";
#     - Colar "git pull" (Atualiza o repositório local com base no repositório remoto);
#     - Copiar o material importado para o diretório individual: "cp -r ~/projects/PythonCourse/"Semana <número da semana>" ~/projects/<nome do vosso repositório>";
# - Ativar o ambiente virtual: Colar "source ~/.virtualenvs/python-venv/bin/activate";
# - Instalar os packages python da respetiva semana:
#     - Colar "pip install -r ~/projects/<nome do vosso repositório>/"Semana <número da semana>"/requirements.txt";
#     - O ficheiro "requirements.txt" serve apenas para informar "pip" quais os packages a instalar, e se especificado, qual versão dos mesmos;
# - Entrar no repositório individual: Colar "cd ~/projects/<nome do vosso repositório>";
# - Iniciar a aplicação Jupyter: Colar "jupyter notebook";
# - Trabalhar;
# - Guardar o trabalho;
# - Fechar o terminal e abrir um novo;
# - Colar "cd ~/projects/<nome do vosso repositório>";
# - Colar "git add .";
# - Colar " git commit -m "Trabalho da semana <número da semana>" " (a frase após o comando é apenas uma descrição do respetivo commit);
# - Colar "git push";
# - Well done :)
